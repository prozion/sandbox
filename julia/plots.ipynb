# %%
using Plots

y = randn(100)
histogram(y)

# %%
scatter(randn(100), randn(100))

# %%
x = -10:10
y1 = x.^4 .- 30*x.^3 .+ 150*x.^2 .- 700*x .+ 3
y2 = (1.5*x .- 5).^-16
p1 = plot(x, y1)
p2 = plot!(x, y2)
